# %% [markdown]
# ## Diabetes Data Set :

# %% [markdown]
# ## Steps:
# 1. Loading dataset & assigning them to X & Y data matrices
# 2. Data Split
# 3. Build Linear Regression Model
# 4. Evaluating model performance

# %% [markdown]
# ## Step 1: Load data & assigning them to X and Y matrices

# %%
## Loading dataset:

from sklearn import datasets
import pandas as pd

# %%
## Loading dataset
data = datasets.load_diabetes()

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'DESCR', 'feature_names'])

# %% [markdown]
# ### Data description

# %%
print(data.DESCR)
# Out:
# Diabetes dataset
# ...
#
# Notes
# -----
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# Data Set Characteristics:
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attributes:
#     :Age:
#     :Sex:
#     :Body mass index:
#     :Average blood pressure:
#     :S1:
#     :S2:
#     :S3:
#     :S4:
#     :S5:
#     :S6:
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# http://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# ...

# %%
df = pd.DataFrame(data.data,columns=data.feature_names)
df['target'] = pd.Series(data.target)
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7    0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9   -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
# 10  -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561 -0.013948
# 11   0.027178  0.050680  0.017506 -0.033214 -0.007073  0.045972 -0.065491
# ...

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %% [markdown]
# ## Creating X & Y Data matrices :

# %%
## Creating X & Y matrices :
X = data.data
Y = data.target

# %%
X.shape ,  Y.shape
# X contains 442 rows and 10 columns , Y contains 442 rows & 1 column
# Out:
# ((442, 10), (442,))

# %%
## Step 1 can be done inn one simple method:
X,Y = datasets.load_diabetes(return_X_y=True)
X.shape , Y.shape
# Out:
# ((442, 10), (442,))

# %% [markdown]
# ## Setp 2 : Splitting Data to train & split (80/20 Split)

# %%
## 1. importing libraries :
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X, Y ,test_size = 0.2) ## 80% train, 20% test

# %%
## Data shape : ** num rows has to be same allways 
X_train.shape,Y_train.shape
# Out:
# ((353, 10), (353,))

# %%
X_test.shape , Y_test.shape
# Out:
# ((89, 10), (89,))

# %% [markdown]
# ## Step 3: Build Linear Regression Model

# %%
## Importing libraries :
from sklearn import linear_model ## model library 
from sklearn.metrics import mean_squared_error,r2_score ## testing performance of our model, metrics which are required

# %%
model = linear_model.LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred
# Out:
# array([156.04642209, 224.94117622,  85.00738812, 162.35537783,
#         80.23406603, 178.45205851, 105.8174544 , 224.70095976,
#         79.20784911, 157.93826194, 107.85516235, 140.11444401,
#        147.93304056, 230.19008526, 190.1174593 , 169.58319412,
#        248.99292649, 211.32545898,  98.21497782, 260.06616848,
#        177.43523301,  97.45564498,  54.64537374, 118.97496032,
#        131.50889604, 185.08088674, 207.13660412, 233.86103648,
#        104.92171272, 215.70262638, 111.14311812, 130.72460541,
#        244.41707228,  88.25311224, 208.36860203, 111.07736205,
#        146.48126306, 202.40334504,  86.28108044, 145.64370428,
#        239.74644834,  92.3399212 , 187.95912484, 190.74983383,
#         94.63974339, 196.96179823, 141.57952154, 149.13366155,
#        127.87866873, 195.41976114, 181.81628914, 248.53338018,
#        142.24108775, 150.71198939, 185.77007   , 118.75033425,
#        123.84405917, 160.92585736, 190.19438985, 174.83786388,
# ...

# %% [markdown]
# ## Step 4 : Evaluating model performance

# %%
## Step 4 : Evaluating model performance
print("Coefficients:",model.coef_) ## This represnt the weight values of the 10 features(variable)
print("Intercept:",model.intercept_)
## %.2f is used for string formatting using modulo 
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_test, Y_pred))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_test, Y_pred))
# Out:
# Coefficients: [  24.78038439 -222.84546279  469.52578132  305.25501325 -795.33214776
#   541.55192835   76.98023561  143.77003976  708.55090028   99.30375976]
# Intercept: 153.71890384173327
# Mean squared error (MSE): 2234.15
# Coefficient of determination (R^2): 0.64

# %%
data.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %% [markdown]
# ## So, the formula of linear regression is y = mx +c , c is the intercept , m are the coefficents & x is the variable
# Y = 24.78*(age)+ (-)222.84*(sex) +69.52*(bmi)+......+ 153.71 (which is the intercept)

# %%
## Look at the data: visualization
import seaborn as sns

# %%
# 1. make scatter plot :
Y_test
# Out:
# array([ 85., 248.,  92., 237.,  59.,  66.,  63., 128.,  37., 141., 142.,
#         90., 202., 280., 164., 128., 273., 297.,  91., 263., 143.,  54.,
#         48.,  69.,  67.,  84., 220., 258.,  72., 275., 108., 111., 275.,
#         49., 150.,  61., 115., 265.,  42.,  61., 215.,  93., 170., 191.,
#        115., 220., 170., 146., 177., 233., 124., 277.,  83.,  95., 164.,
#         88., 113., 118., 178., 122., 292.,  59., 236., 144., 276.,  95.,
#        129.,  84., 141.,  65., 200., 274.,  77.,  57., 308., 200.,  49.,
#        346., 257.,  83., 217., 141.,  81., 104.,  51., 107., 131., 187.,
#        184.])

# %%
Y_pred
# Out:
# array([156.04642209, 224.94117622,  85.00738812, 162.35537783,
#         80.23406603, 178.45205851, 105.8174544 , 224.70095976,
#         79.20784911, 157.93826194, 107.85516235, 140.11444401,
#        147.93304056, 230.19008526, 190.1174593 , 169.58319412,
#        248.99292649, 211.32545898,  98.21497782, 260.06616848,
#        177.43523301,  97.45564498,  54.64537374, 118.97496032,
#        131.50889604, 185.08088674, 207.13660412, 233.86103648,
#        104.92171272, 215.70262638, 111.14311812, 130.72460541,
#        244.41707228,  88.25311224, 208.36860203, 111.07736205,
#        146.48126306, 202.40334504,  86.28108044, 145.64370428,
#        239.74644834,  92.3399212 , 187.95912484, 190.74983383,
#         94.63974339, 196.96179823, 141.57952154, 149.13366155,
#        127.87866873, 195.41976114, 181.81628914, 248.53338018,
#        142.24108775, 150.71198939, 185.77007   , 118.75033425,
#        123.84405917, 160.92585736, 190.19438985, 174.83786388,
# ...

# %%
sns.scatterplot(Y_test,Y_pred,markers='+')

# %%
sns.scatterplot(Y_test,Y_pred,alpha=0.5)
